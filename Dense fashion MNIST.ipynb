# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# # The Sequential model API

# %% [markdown]
# ***
# <a id="coding_tutorial_1"></a>
# ## Building a Sequential model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %% [markdown]
# #### Build a convolutional neural network model

# %%
model = Sequential([
    Flatten(input_shape = (28,28), name="input"),
    Dense(16, activation="relu"),                  
    Dense(16, activation="relu"),                  
    Dense(10, activation="softmax", name="output")                                     
])

# %%
# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (Flatten)             (None, 784)               0
#
#  dense (Dense)               (None, 16)                12560
#
#  dense_1 (Dense)             (None, 16)                272
#
#  output (Dense)              (None, 10)                170
#
# =================================================================
# Total params: 13,002
# Trainable params: 13,002
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ***
# <a id="coding_tutorial_3"></a>
# ## The compile method

# %% [markdown]
# #### Compile the model

# %%
# Define the model optimizer, loss function and metrics
# define optimizer as an objetc
opt = tf.keras.optimizers.Adam(learning_rate=.0005)
acc = tf.keras.metrics.SparseCategoricalAccuracy()
mae = tf.keras.metrics.MeanAbsoluteError()

model.compile(optimizer = opt,
              loss = 'sparse_categorical_crossentropy',
              metrics = [acc, mae]
              )

# %%
# Print the resulting model attributes

print(model.loss)
print(model.optimizer)
print(model.metrics_names)
print(model.optimizer.learning_rate)
# Out:
# sparse_categorical_crossentropy
# <keras.optimizer_v2.adam.Adam object at 0x7fce6c6d1850>
# []
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0005>

# %% [markdown]
# ***
# <a id="coding_tutorial_4"></a>
# ## The fit method

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### Load the data

# %%
# Load the Fashion-MNIST dataset

fashion_mnist_data = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist_data.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# Print the shape of the training data
print(train_images.shape)
print(train_labels.shape)
train_labels
# Out:
# (60000, 28, 28)
# (60000,)
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
# Define the labels

labels = [
    'T-shirt/top',
    'Trouser',
    'Pullover',
    'Dress',
    'Coat',
    'Sandal',
    'Shirt',
    'Sneaker',
    'Bag',
    'Ankle boot'
]

# %%
# Rescale the image values so that they lie in between 0 and 1.

train_images = train_images/255.0
test_images = test_images/255.0

# %%
# Display one of the images
plt.imshow(train_images[0])
plt.show()
print(f"label : {labels[train_labels[0]]}")
# Out:
# label : Ankle boot

# %% [markdown]
# #### Fit the model

# %%
# Fit the model
history = model.fit(train_images[...,np.newaxis],train_labels, batch_size= 256, epochs= 20)
# Out:
# Epoch 1/20
# 235/235 [==============================] - 2s 5ms/step - loss: 1.2799 - sparse_categorical_accuracy: 0.5976 - mean_absolute_error: 4.4200
# Epoch 2/20
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5903 - sparse_categorical_accuracy: 0.8021 - mean_absolute_error: 4.4200
# Epoch 3/20
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5109 - sparse_categorical_accuracy: 0.8264 - mean_absolute_error: 4.4200
# Epoch 4/20
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4740 - sparse_categorical_accuracy: 0.8363 - mean_absolute_error: 4.4200
# Epoch 5/20
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4518 - sparse_categorical_accuracy: 0.8439 - mean_absolute_error: 4.4200
# Epoch 6/20
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4346 - sparse_categorical_accuracy: 0.8498 - mean_absolute_error: 4.4200
# Epoch 7/20
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4230 - sparse_categorical_accuracy: 0.8539 - mean_absolute_error: 4.4200
# Epoch 8/20
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4135 - sparse_categorical_accuracy: 0.8568 - mean_absolute_error: 4.4200
# Epoch 9/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4062 - sparse_categorical_accuracy: 0.8594 - mean_absolute_error: 4.4200
# Epoch 10/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4003 - sparse_categorical_accuracy: 0.8601 - mean_absolute_error: 4.4200
# Epoch 11/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3939 - sparse_categorical_accuracy: 0.8629 - mean_absolute_error: 4.4200
# Epoch 12/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3885 - sparse_categorical_accuracy: 0.8655 - mean_absolute_error: 4.4200
# Epoch 13/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3843 - sparse_categorical_accuracy: 0.8657 - mean_absolute_error: 4.4200
# Epoch 14/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3801 - sparse_categorical_accuracy: 0.8667 - mean_absolute_error: 4.4200
# Epoch 15/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3768 - sparse_categorical_accuracy: 0.8676 - mean_absolute_error: 4.4200
# Epoch 16/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3745 - sparse_categorical_accuracy: 0.8684 - mean_absolute_error: 4.4200
# Epoch 17/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3709 - sparse_categorical_accuracy: 0.8694 - mean_absolute_error: 4.4200
# Epoch 18/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3664 - sparse_categorical_accuracy: 0.8721 - mean_absolute_error: 4.4200
# Epoch 19/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3646 - sparse_categorical_accuracy: 0.8724 - mean_absolute_error: 4.4200
# Epoch 20/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3624 - sparse_categorical_accuracy: 0.8725 - mean_absolute_error: 4.4200

# %% [markdown]
# #### Plot training history

# %%
# Load the history into a pandas Dataframe

df = pd.DataFrame(history.history)
df
# Out:
#         loss  sparse_categorical_accuracy  mean_absolute_error
# 0   1.279948                     0.597567             4.419999
# 1   0.590276                     0.802117             4.419999
# 2   0.510904                     0.826367             4.420000
# 3   0.473984                     0.836317             4.420000
# 4   0.451821                     0.843850             4.420000
# 5   0.434643                     0.849767             4.419999
# 6   0.422998                     0.853883             4.419999
# 7   0.413474                     0.856767             4.420001
# 8   0.406225                     0.859367             4.420000
# 9   0.400284                     0.860067             4.420000
# 10  0.393931                     0.862850             4.419999
# 11  0.388483                     0.865467             4.420000
# 12  0.384338                     0.865683             4.419999
# 13  0.380091                     0.866700             4.420000
# 14  0.376838                     0.867633             4.419999
# 15  0.374487                     0.868350             4.420002
# 16  0.370873                     0.869383             4.420000
# 17  0.366371                     0.872133             4.420000
# 18  0.364629                     0.872450             4.420001
# 19  0.362412                     0.872517             4.420000

# %%
# Make a plot for the loss

df.plot( y = "loss", title = "Loss vs Epoch")

# %%
# Make a plot for the accuracy

df.plot( y = "sparse_categorical_accuracy", title = "sparse_categorical_accuracy vs Epoch")

# %%
# Make a plot for the additional metric
df.plot( y = "mean_absolute_error", title = "mean_absolute_error vs Epoch")

# %% [markdown]
# ***
# <a id="coding_tutorial_5"></a>
# ## The evaluate and predict methods

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Evaluate the model on the test set

# %%
print(test_images.shape)
print(test_images[...,np.newaxis].shape)
# Out:
# (10000, 28, 28)
# (10000, 28, 28, 1)

# %%
# Evaluate the model
loss, accuracy, mae = model.evaluate(test_images[...,np.newaxis], test_labels)
print("loss", loss)
print("acc", accuracy)
print("mae", mae)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.4169 - sparse_categorical_accuracy: 0.8529 - mean_absolute_error: 4.4200
# loss 0.4169141948223114
# acc 0.8529000282287598
# mae 4.419997215270996

# %% [markdown]
# #### Make predictions from the model

# %%
# Choose a random test image

random_inx = np.random.choice(test_images.shape[0])

test_image = test_images[random_inx]
plt.imshow(test_image)
plt.show()
print(f"Label: {labels[test_labels[random_inx]]}")
# Out:
# Label: Dress

# %%
# Get the model predictions
pred = model.predict(test_image[np.newaxis,...,np.newaxis])
print("Model", labels[np.argmax(pred)])
# Out:
# Model Dress

# %%
pred
# Out:
# array([[1.1301212e-03, 3.7512640e-05, 1.5891944e-03, 9.8052877e-01,
#         1.4338655e-02, 6.9929484e-07, 2.3448970e-03, 6.1541091e-06,
#         2.3831142e-05, 1.2593820e-07]], dtype=float32)

# %%
import pandas as pd
df = pd.DataFrame(pred)
df
# Out:
#          0         1         2         3         4             5         6  \
# 0  0.00113  0.000038  0.001589  0.980529  0.014339  6.992948e-07  0.002345
#
#           7         8             9
# 0  0.000006  0.000024  1.259382e-07

# %%
df.plot.bar()
